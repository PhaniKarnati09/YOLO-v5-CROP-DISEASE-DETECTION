# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_update.zip" -d "/content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_ultralatics"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_ultralatics/PlantVillage_yolov5/train/labels/5499.txt
#   inflating: /content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_ultralatics/PlantVillage_yolov5/train/labels/55.txt
#   inflating: /content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_ultralatics/PlantVillage_yolov5/train/labels/550.txt
#   inflating: /content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_ultralatics/PlantVillage_yolov5/train/labels/5500.txt
#   inflating: /content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_ultralatics/PlantVillage_yolov5/train/labels/5501.txt
#   inflating: /content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_ultralatics/PlantVillage_yolov5/train/labels/5502.txt
#   inflating: /content/drive/MyDrive/dataset/PlantVillage_yolov5_evening_ultralatics/PlantVillage_yolov5/train/labels/5503.txt
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-261-g19f33cb Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
# Train YOLOv5s on COCO128 for 3 epochs ---* epoch 100 
# !python train.py --img 416 --batch 32 --epochs 20 --data data_v5.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data_v5.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-261-g19f33cb Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
